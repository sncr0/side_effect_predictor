# %%
import csv
import pandas as pd
import numpy as np

# %%
def read_tsv_file(file_path, headers = True):
    try:
        data = []
        with open(file_path, 'r', newline='', encoding='utf-8') as file:
            # Using the CSV reader with the tab delimiter
            reader = csv.reader(file, delimiter='\t')

            if headers == True:
                # Reading headers
                headers = next(reader)
                print("Headers:", headers)

            # Reading data rows
            for row in reader:
                data.append(row)

        # Create a Pandas DataFrame using the headers and data
        if headers == True:
            df = pd.DataFrame(data, columns=headers)
        else:
            df = pd.DataFrame(data) #, columns=headers)
        return df

    except FileNotFoundError:
        print(f"Error: File not found at '{file_path}'")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
dataset_path = "/home/samuel/NYU/BDS/project/meddra/"
meddra_file_path = dataset_path + 'meddra_all_se.tsv'
meddra_df = read_tsv_file(meddra_file_path, headers = False)

# %%
drug_names_file_path = "/home/samuel/NYU/BDS/project/sider/" + 'drug_names.tsv'
drug_names_df = read_tsv_file(drug_names_file_path, headers = False)
drug_names_df = drug_names_df.rename(columns={0: "CID", 1: "drug_name"})

# %%
processed_dataset = pd.read_csv("../review_dataset/drugsComTrain_processed.csv")

# %%
drug_counts = processed_dataset['drugName'].value_counts()[processed_dataset['drugName'].value_counts() > 100].reset_index().rename(columns={'drugName': 'drug_name', 'count': 'count'})
drug_counts['drug_name_lower'] = drug_counts['drug_name'].str.lower()

merged_df = pd.merge(drug_counts, drug_names_df, left_on='drug_name_lower', right_on="drug_name", how='inner')

merged_df.drop(['drug_name_lower','drug_name_y'], axis=1, inplace=True)
merged_df = merged_df.rename(columns = {"drug_name_x": "drug_name"})

merged_df
# Out:
#           drug_name  count           CID
# 0    Levonorgestrel   3657  CID100004542
# 1       Phentermine   1543  CID100004771
# 2        Sertraline   1360  CID100005203
# 3        Gabapentin   1047  CID100003446
# 4         Bupropion   1022  CID100000444
# ..              ...    ...           ...
# 148       Celecoxib    109  CID100002662
# 149      Cetirizine    108  CID100002678
# 150    Paliperidone    104  CID100115237
# 151       Melatonin    103  CID100000896
# 152    Indomethacin    103  CID100003715
#
# [153 rows x 3 columns]

# %%
from fuzzywuzzy import fuzz
import pandas as pd

# Assuming drug_counts and drug_names_df are your DataFrames
# and you have already created the 'drug_name_lower' column in drug_counts

# Function to perform approximate matching
def fuzzy_merge(df1, df2, key1, key2, threshold=90):
    """
    Perform fuzzy matching between two DataFrames on specified columns.
    """
    matched_pairs = []
    for idx1, row1 in df1.iterrows():
        print(row1)
        for idx2, row2 in df2.iterrows():
            if fuzz.partial_ratio(row1[key1], row2[key2]) >= threshold:
                matched_pairs.append((idx1, idx2))
    return matched_pairs

# Call the fuzzy_merge function to perform approximate matching
matched_indices = fuzzy_merge(drug_counts, drug_names_df, 'drug_name_lower', 'drug_name', threshold=90)

# Create a DataFrame with the matched indices
matched_df = pd.DataFrame(matched_indices, columns=['idx1', 'idx2'])

# Merge drug_counts and drug_names_df using the matched indices
merged_df = pd.merge(matched_df, drug_counts, left_on='idx1', right_index=True)
merged_df = pd.merge(merged_df, drug_names_df, left_on='idx2', right_index=True)

# Drop unnecessary columns
merged_df.drop(['idx1', 'idx2', 'drug_name_lower', 'drug_name_y'], axis=1, inplace=True)
merged_df.rename(columns={"drug_name_x": "drug_name"}, inplace=True)

print(merged_df)
# Out:
# drug_name          Levonorgestrel
# count                        3657
# drug_name_lower    levonorgestrel
# Name: 0, dtype: object
# drug_name          Etonogestrel
# count                      3336
# drug_name_lower    etonogestrel
# Name: 1, dtype: object
# drug_name          Ethinyl estradiol / norethindrone
# count                                           2850
# drug_name_lower    ethinyl estradiol / norethindrone
# Name: 2, dtype: object
# drug_name          Nexplanon
# count                   2156
# drug_name_lower    nexplanon
# Name: 3, dtype: object
# drug_name          Ethinyl estradiol / norgestimate
# count                                          2117
# drug_name_lower    ethinyl estradiol / norgestimate
# Name: 4, dtype: object
# drug_name          Ethinyl estradiol / levonorgestrel
# count                                            1888
# drug_name_lower    ethinyl estradiol / levonorgestrel
# Name: 5, dtype: object
# drug_name          Phentermine
# count                     1543
# drug_name_lower    phentermine
# Name: 6, dtype: object
# drug_name          Sertraline
# count                    1360
# drug_name_lower    sertraline
# Name: 7, dtype: object
# drug_name          Escitalopram
# count                      1292
# drug_name_lower    escitalopram
# Name: 8, dtype: object
# drug_name          Mirena
# count                1242
# drug_name_lower    mirena
# Name: 9, dtype: object
# drug_name          Implanon
# count                  1102
# drug_name_lower    implanon
# Name: 10, dtype: object
# drug_name          Gabapentin
# count                    1047
# drug_name_lower    gabapentin
# Name: 11, dtype: object
# drug_name          Bupropion
# count                   1022
# drug_name_lower    bupropion
# Name: 12, dtype: object
# drug_name          Venlafaxine
# count                     1016
# drug_name_lower    venlafaxine
# Name: 13, dtype: object
# drug_name          Miconazole
# count                    1000
# drug_name_lower    miconazole
# Name: 14, dtype: object
# drug_name          Medroxyprogesterone
# count                              995
# drug_name_lower    medroxyprogesterone
# Name: 15, dtype: object
# drug_name          Citalopram
# count                     995
# drug_name_lower    citalopram
# Name: 16, dtype: object
# drug_name          Lexapro
# count                  952
# drug_name_lower    lexapro
# Name: 17, dtype: object
# drug_name          Bupropion / naltrexone
# count                                 950
# drug_name_lower    bupropion / naltrexone
# Name: 18, dtype: object
# drug_name          Duloxetine
# count                     934
# drug_name_lower    duloxetine
# Name: 19, dtype: object
# drug_name          Metronidazole
# count                        922
# drug_name_lower    metronidazole
# Name: 20, dtype: object
# drug_name          Contrave
# count                   920
# drug_name_lower    contrave
# Name: 21, dtype: object
# drug_name          Drospirenone / ethinyl estradiol
# count                                           890
# drug_name_lower    drospirenone / ethinyl estradiol
# Name: 22, dtype: object
# drug_name          Depo-Provera
# count                       882
# drug_name_lower    depo-provera
# Name: 23, dtype: object
# drug_name          Cymbalta
# count                   864
# drug_name_lower    cymbalta
# Name: 24, dtype: object
# drug_name          Quetiapine
# count                     831
# drug_name_lower    quetiapine
# Name: 25, dtype: object
# drug_name          Clonazepam
# count                     831
# drug_name_lower    clonazepam
# Name: 26, dtype: object
# drug_name          Skyla
# count                824
# drug_name_lower    skyla
# Name: 27, dtype: object
# drug_name          Tramadol
# count                   820
# drug_name_lower    tramadol
# Name: 28, dtype: object
# drug_name          Zoloft
# count                 805
# drug_name_lower    zoloft
# Name: 29, dtype: object
# drug_name          Varenicline
# count                      794
# drug_name_lower    varenicline
# Name: 30, dtype: object
# drug_name          Fluoxetine
# count                     766
# drug_name_lower    fluoxetine
# Name: 31, dtype: object
# drug_name          Liraglutide
# count                      755
# drug_name_lower    liraglutide
# Name: 32, dtype: object
# drug_name          Tioconazole
# count                      706
# drug_name_lower    tioconazole
# Name: 33, dtype: object
# drug_name          Alprazolam
# count                     703
# drug_name_lower    alprazolam
# Name: 34, dtype: object
# drug_name          Amitriptyline
# count                        695
# drug_name_lower    amitriptyline
# Name: 35, dtype: object
# drug_name          Lo Loestrin Fe
# count                         680
# drug_name_lower    lo loestrin fe
# Name: 36, dtype: object
# drug_name          Paroxetine
# count                     645
# drug_name_lower    paroxetine
# Name: 37, dtype: object
# drug_name          Chantix
# count                  637
# drug_name_lower    chantix
# Name: 38, dtype: object
# drug_name          Ethinyl estradiol / etonogestrel
# count                                           635
# drug_name_lower    ethinyl estradiol / etonogestrel
# Name: 39, dtype: object
# drug_name          Pregabalin
# count                     632
# drug_name_lower    pregabalin
# Name: 40, dtype: object
# drug_name          Doxycycline
# count                      627
# drug_name_lower    doxycycline
# Name: 41, dtype: object
# drug_name          Magnesium sulfate / potassium sulfate / sodium...
# count                                                            626
# drug_name_lower    magnesium sulfate / potassium sulfate / sodium...
# Name: 42, dtype: object
# drug_name          NuvaRing
# count                   622
# drug_name_lower    nuvaring
# Name: 43, dtype: object
# drug_name          Copper
# count                 608
# drug_name_lower    copper
# Name: 44, dtype: object
# drug_name          Plan B
# count                 606
# drug_name_lower    plan b
# Name: 45, dtype: object
# drug_name          Topiramate
# count                     606
# drug_name_lower    topiramate
# Name: 46, dtype: object
# drug_name          Suprep Bowel Prep Kit
# count                                598
# drug_name_lower    suprep bowel prep kit
# Name: 47, dtype: object
# drug_name          Lamotrigine
# count                      591
# drug_name_lower    lamotrigine
# Name: 48, dtype: object
# drug_name          Trazodone
# count                    584
# drug_name_lower    trazodone
# Name: 49, dtype: object
# drug_name          Desvenlafaxine
# count                         582
# drug_name_lower    desvenlafaxine
# Name: 50, dtype: object
# drug_name          Lorcaserin
# count                     572
# drug_name_lower    lorcaserin
# Name: 51, dtype: object
# drug_name          Belviq
# count                 563
# drug_name_lower    belviq
# Name: 52, dtype: object
# drug_name          Azithromycin
# count                       548
# drug_name_lower    azithromycin
# Name: 53, dtype: object
# drug_name          Pristiq
# count                  548
# drug_name_lower    pristiq
# Name: 54, dtype: object
# drug_name          Mirtazapine
# count                      546
# drug_name_lower    mirtazapine
# Name: 55, dtype: object
# drug_name          Isotretinoin
# count                       530
# drug_name_lower    isotretinoin
# Name: 56, dtype: object
# drug_name          Sulfamethoxazole / trimethoprim
# count                                          527
# drug_name_lower    sulfamethoxazole / trimethoprim
# Name: 57, dtype: object
# drug_name          Desogestrel / ethinyl estradiol
# count                                          522
# drug_name_lower    desogestrel / ethinyl estradiol
# Name: 58, dtype: object
# drug_name          Sprintec
# count                   509
# drug_name_lower    sprintec
# Name: 59, dtype: object
# drug_name          Vortioxetine
# count                       507
# drug_name_lower    vortioxetine
# Name: 60, dtype: object
# drug_name          Nitrofurantoin
# count                         500
# drug_name_lower    nitrofurantoin
# Name: 61, dtype: object
# drug_name          Bisacodyl
# count                    500
# drug_name_lower    bisacodyl
# Name: 62, dtype: object
# drug_name          Aripiprazole
# count                       500
# drug_name_lower    aripiprazole
# Name: 63, dtype: object
# drug_name          Acetaminophen / hydrocodone
# count                                      498
# drug_name_lower    acetaminophen / hydrocodone
# Name: 64, dtype: object
# drug_name          Celexa
# count                 491
# drug_name_lower    celexa
# Name: 65, dtype: object
# drug_name          Loestrin 24 Fe
# count                         486
# drug_name_lower    loestrin 24 fe
# Name: 66, dtype: object
# drug_name          Diclofenac
# count                     482
# drug_name_lower    diclofenac
# Name: 67, dtype: object
# drug_name          Zolpidem
# count                   482
# drug_name_lower    zolpidem
# Name: 68, dtype: object
# drug_name          Oxycodone
# count                    472
# drug_name_lower    oxycodone
# Name: 69, dtype: object
# drug_name          Prozac
# count                 472
# drug_name_lower    prozac
# Name: 70, dtype: object
# drug_name          Buspirone
# count                    471
# drug_name_lower    buspirone
# Name: 71, dtype: object
# drug_name          Propranolol
# count                      467
# drug_name_lower    propranolol
# Name: 72, dtype: object
# drug_name          Lisdexamfetamine
# count                           461
# drug_name_lower    lisdexamfetamine
# Name: 73, dtype: object
# drug_name          Paxil
# count                457
# drug_name_lower    paxil
# Name: 74, dtype: object
# drug_name          Methylphenidate
# count                          456
# drug_name_lower    methylphenidate
# Name: 75, dtype: object
# drug_name          Xanax
# count                456
# drug_name_lower    xanax
# Name: 76, dtype: object
# drug_name          Hydroxyzine
# count                      448
# drug_name_lower    hydroxyzine
# Name: 77, dtype: object
# drug_name          Abilify
# count                  446
# drug_name_lower    abilify
# Name: 78, dtype: object
# drug_name          Lyrica
# count                 441
# drug_name_lower    lyrica
# Name: 79, dtype: object
# drug_name          Buprenorphine / naloxone
# count                                   437
# drug_name_lower    buprenorphine / naloxone
# Name: 80, dtype: object
# drug_name          Vyvanse
# count                  434
# drug_name_lower    vyvanse
# Name: 81, dtype: object
# drug_name          Klonopin
# count                   432
# drug_name_lower    klonopin
# Name: 82, dtype: object
# drug_name          Norethindrone
# count                        431
# drug_name_lower    norethindrone
# Name: 83, dtype: object
# drug_name          Lorazepam
# count                    429
# drug_name_lower    lorazepam
# Name: 84, dtype: object
# drug_name          Vilazodone
# count                     427
# drug_name_lower    vilazodone
# Name: 85, dtype: object
# drug_name          Plan B One-Step
# count                          425
# drug_name_lower    plan b one-step
# Name: 86, dtype: object
# drug_name          Amphetamine / dextroamphetamine
# count                                          419
# drug_name_lower    amphetamine / dextroamphetamine
# Name: 87, dtype: object
# drug_name          Adapalene / benzoyl peroxide
# count                                       399
# drug_name_lower    adapalene / benzoyl peroxide
# Name: 88, dtype: object
# drug_name          Effexor XR
# count                     399
# drug_name_lower    effexor xr
# Name: 89, dtype: object
# drug_name          Dulcolax
# count                   396
# drug_name_lower    dulcolax
# Name: 90, dtype: object
# drug_name          Epiduo
# count                 396
# drug_name_lower    epiduo
# Name: 91, dtype: object
# drug_name          Trintellix
# count                     395
# drug_name_lower    trintellix
# Name: 92, dtype: object
# drug_name          Tri-Sprintec
# count                       392
# drug_name_lower    tri-sprintec
# Name: 93, dtype: object
# drug_name          Microgestin Fe 1 / 20
# count                                392
# drug_name_lower    microgestin fe 1 / 20
# Name: 94, dtype: object
# drug_name          Clindamycin
# count                      385
# drug_name_lower    clindamycin
# Name: 95, dtype: object
# drug_name          Viibryd
# count                  375
# drug_name_lower    viibryd
# Name: 96, dtype: object
# drug_name          Ethinyl estradiol / norelgestromin
# count                                             374
# drug_name_lower    ethinyl estradiol / norelgestromin
# Name: 97, dtype: object
# drug_name          ParaGard
# count                   369
# drug_name_lower    paragard
# Name: 98, dtype: object
# drug_name          Acetaminophen / oxycodone
# count                                    362
# drug_name_lower    acetaminophen / oxycodone
# Name: 99, dtype: object
# drug_name          Ciprofloxacin
# count                        361
# drug_name_lower    ciprofloxacin
# Name: 100, dtype: object
# drug_name          Phentermine / topiramate
# count                                   359
# drug_name_lower    phentermine / topiramate
# Name: 101, dtype: object
# drug_name          Suboxone
# count                   355
# drug_name_lower    suboxone
# Name: 102, dtype: object
# drug_name          Lurasidone
# count                     352
# drug_name_lower    lurasidone
# Name: 103, dtype: object
# drug_name          Saxenda
# count                  345
# drug_name_lower    saxenda
# Name: 104, dtype: object
# drug_name          Yaz
# count              344
# drug_name_lower    yaz
# Name: 105, dtype: object
# drug_name          Victoza
# count                  344
# drug_name_lower    victoza
# Name: 106, dtype: object
# drug_name          Topamax
# count                  340
# drug_name_lower    topamax
# Name: 107, dtype: object
# drug_name          Lamictal
# count                   339
# drug_name_lower    lamictal
# Name: 108, dtype: object
# drug_name          Linaclotide
# count                      337
# drug_name_lower    linaclotide
# Name: 109, dtype: object
# drug_name          Seroquel
# count                   334
# drug_name_lower    seroquel
# Name: 110, dtype: object
# drug_name          Latuda
# count                 330
# drug_name_lower    latuda
# Name: 111, dtype: object
# drug_name          Accutane
# count                   330
# drug_name_lower    accutane
# Name: 112, dtype: object
# drug_name          Methadone
# count                    328
# drug_name_lower    methadone
# Name: 113, dtype: object
# drug_name          Levofloxacin
# count                       327
# drug_name_lower    levofloxacin
# Name: 114, dtype: object
# drug_name          Adipex-P
# count                   326
# drug_name_lower    adipex-p
# Name: 115, dtype: object
# drug_name          Linzess
# count                  324
# drug_name_lower    linzess
# Name: 116, dtype: object
# drug_name          Aluminum chloride hexahydrate
# count                                        323
# drug_name_lower    aluminum chloride hexahydrate
# Name: 117, dtype: object
# drug_name          Diazepam
# count                   322
# drug_name_lower    diazepam
# Name: 118, dtype: object
# drug_name          Amoxicillin / clavulanate
# count                                    321
# drug_name_lower    amoxicillin / clavulanate
# Name: 119, dtype: object
# drug_name          Tadalafil
# count                    318
# drug_name_lower    tadalafil
# Name: 120, dtype: object
# drug_name          Clonidine
# count                    315
# drug_name_lower    clonidine
# Name: 121, dtype: object
# drug_name          Qsymia
# count                 312
# drug_name_lower    qsymia
# Name: 122, dtype: object
# drug_name          Naproxen
# count                   308
# drug_name_lower    naproxen
# Name: 123, dtype: object
# drug_name          Adalimumab
# count                     295
# drug_name_lower    adalimumab
# Name: 124, dtype: object
# drug_name          Humira
# count                 295
# drug_name_lower    humira
# Name: 125, dtype: object
# drug_name          Lisinopril
# count                     292
# drug_name_lower    lisinopril
# Name: 126, dtype: object
# drug_name          Clarithromycin
# count                         291
# drug_name_lower    clarithromycin
# Name: 127, dtype: object
# drug_name          Levothyroxine
# count                        290
# drug_name_lower    levothyroxine
# Name: 128, dtype: object
# drug_name          Prednisone
# count                     289
# drug_name_lower    prednisone
# Name: 129, dtype: object
# drug_name          Buprenorphine
# count                        288
# drug_name_lower    buprenorphine
# Name: 130, dtype: object
# drug_name          Ambien
# count                 288
# drug_name_lower    ambien
# Name: 131, dtype: object
# drug_name          Wellbutrin
# count                     281
# drug_name_lower    wellbutrin
# Name: 132, dtype: object
# drug_name          Cialis
# count                 279
# drug_name_lower    cialis
# Name: 133, dtype: object
# drug_name          Olanzapine
# count                     278
# drug_name_lower    olanzapine
# Name: 134, dtype: object
# drug_name          Testosterone
# count                       278
# drug_name_lower    testosterone
# Name: 135, dtype: object
# drug_name          TriNessa
# count                   277
# drug_name_lower    trinessa
# Name: 136, dtype: object
# drug_name          Cyclobenzaprine
# count                          275
# drug_name_lower    cyclobenzaprine
# Name: 137, dtype: object
# drug_name          Sumatriptan
# count                      269
# drug_name_lower    sumatriptan
# Name: 138, dtype: object
# drug_name          Metformin
# count                    268
# drug_name_lower    metformin
# Name: 139, dtype: object
# drug_name          Effexor
# count                  265
# drug_name_lower    effexor
# Name: 140, dtype: object
# drug_name          Hydromorphone
# count                        265
# drug_name_lower    hydromorphone
# Name: 141, dtype: object
# drug_name          Benzoyl peroxide / clindamycin
# count                                         264
# drug_name_lower    benzoyl peroxide / clindamycin
# Name: 142, dtype: object
# drug_name          BuSpar
# count                 264
# drug_name_lower    buspar
# Name: 143, dtype: object
# drug_name          Minocycline
# count                      257
# drug_name_lower    minocycline
# Name: 144, dtype: object
# drug_name          Tretinoin
# count                    250
# drug_name_lower    tretinoin
# Name: 145, dtype: object
# drug_name          Meloxicam
# count                    250
# drug_name_lower    meloxicam
# Name: 146, dtype: object
# drug_name          Aviane
# count                 249
# drug_name_lower    aviane
# Name: 147, dtype: object
# drug_name          Nortriptyline
# count                        241
# drug_name_lower    nortriptyline
# Name: 148, dtype: object
# drug_name          Estradiol
# count                    241
# drug_name_lower    estradiol
# Name: 149, dtype: object
# drug_name          Risperidone
# count                      240
# drug_name_lower    risperidone
# Name: 150, dtype: object
# drug_name          Spironolactone
# count                         239
# drug_name_lower    spironolactone
# Name: 151, dtype: object
# drug_name          Valacyclovir
# count                       238
# drug_name_lower    valacyclovir
# Name: 152, dtype: object
# drug_name          Macrobid
# count                   238
# drug_name_lower    macrobid
# Name: 153, dtype: object
# drug_name          Divalproex sodium
# count                            235
# drug_name_lower    divalproex sodium
# Name: 154, dtype: object
# drug_name          Dulaglutide
# count                      231
# drug_name_lower    dulaglutide
# Name: 155, dtype: object
# drug_name          Fentanyl
# count                   226
# drug_name_lower    fentanyl
# Name: 156, dtype: object
# drug_name          Morphine
# count                   221
# drug_name_lower    morphine
# Name: 157, dtype: object
# drug_name          Tapentadol
# count                     221
# drug_name_lower    tapentadol
# Name: 158, dtype: object
# drug_name          Trulicity
# count                    221
# drug_name_lower    trulicity
# Name: 159, dtype: object
# drug_name          Ativan
# count                 220
# drug_name_lower    ativan
# Name: 160, dtype: object
# drug_name          Seasonique
# count                     220
# drug_name_lower    seasonique
# Name: 161, dtype: object
# drug_name          Junel Fe 1 / 20
# count                          220
# drug_name_lower    junel fe 1 / 20
# Name: 162, dtype: object
# drug_name          Ortho Evra
# count                     219
# drug_name_lower    ortho evra
# Name: 163, dtype: object
# drug_name          Apri
# count               218
# drug_name_lower    apri
# Name: 164, dtype: object
# drug_name          Ortho Tri-Cyclen Lo
# count                              215
# drug_name_lower    ortho tri-cyclen lo
# Name: 165, dtype: object
# drug_name          Metoprolol
# count                     215
# drug_name_lower    metoprolol
# Name: 166, dtype: object
# drug_name          Polyethylene glycol 3350 with electrolytes
# count                                                     213
# drug_name_lower    polyethylene glycol 3350 with electrolytes
# Name: 167, dtype: object
# drug_name          Bactrim
# count                  212
# drug_name_lower    bactrim
# Name: 168, dtype: object
# drug_name          Savella
# count                  212
# drug_name_lower    savella
# Name: 169, dtype: object
# drug_name          Modafinil
# count                    209
# drug_name_lower    modafinil
# Name: 170, dtype: object
# drug_name          Liletta
# count                  209
# drug_name_lower    liletta
# Name: 171, dtype: object
# drug_name          Milnacipran
# count                      207
# drug_name_lower    milnacipran
# Name: 172, dtype: object
# drug_name          Atomoxetine
# count                      206
# drug_name_lower    atomoxetine
# Name: 173, dtype: object
# drug_name          Armodafinil
# count                      206
# drug_name_lower    armodafinil
# Name: 174, dtype: object
# drug_name          Lutera
# count                 205
# drug_name_lower    lutera
# Name: 175, dtype: object
# drug_name          Benzonatate
# count                      203
# drug_name_lower    benzonatate
# Name: 176, dtype: object
# drug_name          Ondansetron
# count                      203
# drug_name_lower    ondansetron
# Name: 177, dtype: object
# drug_name          Levaquin
# count                   202
# drug_name_lower    levaquin
# Name: 178, dtype: object
# drug_name          Wellbutrin XL
# count                        202
# drug_name_lower    wellbutrin xl
# Name: 179, dtype: object
# drug_name          Suvorexant
# count                     201
# drug_name_lower    suvorexant
# Name: 180, dtype: object
# drug_name          Adderall
# count                   201
# drug_name_lower    adderall
# Name: 181, dtype: object
# drug_name          Fluconazole
# count                      200
# drug_name_lower    fluconazole
# Name: 182, dtype: object
# drug_name          Strattera
# count                    200
# drug_name_lower    strattera
# Name: 183, dtype: object
# drug_name          Harvoni
# count                  198
# drug_name_lower    harvoni
# Name: 184, dtype: object
# drug_name          Concerta
# count                   198
# drug_name_lower    concerta
# Name: 185, dtype: object
# drug_name          Dilaudid
# count                   196
# drug_name_lower    dilaudid
# Name: 186, dtype: object
# drug_name          Propofol
# count                   196
# drug_name_lower    propofol
# Name: 187, dtype: object
# drug_name          Ledipasvir / sofosbuvir
# count                                  195
# drug_name_lower    ledipasvir / sofosbuvir
# Name: 188, dtype: object
# drug_name          Exenatide
# count                    194
# drug_name_lower    exenatide
# Name: 189, dtype: object
# drug_name          Asenapine
# count                    194
# drug_name_lower    asenapine
# Name: 190, dtype: object
# drug_name          Tamiflu
# count                  191
# drug_name_lower    tamiflu
# Name: 191, dtype: object
# drug_name          Belsomra
# count                   189
# drug_name_lower    belsomra
# Name: 192, dtype: object
# drug_name          Temazepam
# count                    189
# drug_name_lower    temazepam
# Name: 193, dtype: object
# drug_name          OxyContin
# count                    188
# drug_name_lower    oxycontin
# Name: 194, dtype: object
# drug_name          Oseltamivir
# count                      187
# drug_name_lower    oseltamivir
# Name: 195, dtype: object
# drug_name          Tamsulosin
# count                     181
# drug_name_lower    tamsulosin
# Name: 196, dtype: object
# drug_name          Saphris
# count                  181
# drug_name_lower    saphris
# Name: 197, dtype: object
# drug_name          Naltrexone
# count                     180
# drug_name_lower    naltrexone
# Name: 198, dtype: object
# drug_name          Mesalamine
# count                     179
# drug_name_lower    mesalamine
# Name: 199, dtype: object
# drug_name          Amlodipine
# count                     179
# drug_name_lower    amlodipine
# Name: 200, dtype: object
# drug_name          Ziprasidone
# count                      178
# drug_name_lower    ziprasidone
# Name: 201, dtype: object
# drug_name          Adapalene
# count                    177
# drug_name_lower    adapalene
# Name: 202, dtype: object
# drug_name          Gildess Fe 1 / 20
# count                            175
# drug_name_lower    gildess fe 1 / 20
# Name: 203, dtype: object
# drug_name          Montelukast
# count                      174
# drug_name_lower    montelukast
# Name: 204, dtype: object
# drug_name          Levetiracetam
# count                        174
# drug_name_lower    levetiracetam
# Name: 205, dtype: object
# drug_name          Lithium
# count                  173
# drug_name_lower    lithium
# Name: 206, dtype: object
# drug_name          Terbinafine
# count                      173
# drug_name_lower    terbinafine
# Name: 207, dtype: object
# drug_name          Doxepin
# count                  171
# drug_name_lower    doxepin
# Name: 208, dtype: object
# drug_name          Yasmin
# count                 171
# drug_name_lower    yasmin
# Name: 209, dtype: object
# drug_name          Magnesium citrate
# count                            169
# drug_name_lower    magnesium citrate
# Name: 210, dtype: object
# drug_name          Nuvigil
# count                  169
# drug_name_lower    nuvigil
# Name: 211, dtype: object
# drug_name          Losartan
# count                   169
# drug_name_lower    losartan
# Name: 212, dtype: object
# drug_name          Augmentin
# count                    169
# drug_name_lower    augmentin
# Name: 213, dtype: object
# drug_name          Sildenafil
# count                     167
# drug_name_lower    sildenafil
# Name: 214, dtype: object
# drug_name          Zyprexa
# count                  167
# drug_name_lower    zyprexa
# Name: 215, dtype: object
# drug_name          OnabotulinumtoxinA
# count                             167
# drug_name_lower    onabotulinumtoxina
# Name: 216, dtype: object
# drug_name          Geodon
# count                 165
# drug_name_lower    geodon
# Name: 217, dtype: object
# drug_name          Cipro
# count                165
# drug_name_lower    cipro
# Name: 218, dtype: object
# drug_name          Ketorolac
# count                    164
# drug_name_lower    ketorolac
# Name: 219, dtype: object
# drug_name          Nucynta
# count                  164
# drug_name_lower    nucynta
# Name: 220, dtype: object
# drug_name          Carbamazepine
# count                        163
# drug_name_lower    carbamazepine
# Name: 221, dtype: object
# drug_name          Eszopiclone
# count                      163
# drug_name_lower    eszopiclone
# Name: 222, dtype: object
# drug_name          Orlistat
# count                   161
# drug_name_lower    orlistat
# Name: 223, dtype: object
# drug_name          Botox
# count                160
# drug_name_lower    botox
# Name: 224, dtype: object
# drug_name          Baclofen
# count                   159
# drug_name_lower    baclofen
# Name: 225, dtype: object
# drug_name          Docosanol
# count                    159
# drug_name_lower    docosanol
# Name: 226, dtype: object
# drug_name          Xulane
# count                 159
# drug_name_lower    xulane
# Name: 227, dtype: object
# drug_name          Thyroid desiccated
# count                             159
# drug_name_lower    thyroid desiccated
# Name: 228, dtype: object
# drug_name          Abreva
# count                 158
# drug_name_lower    abreva
# Name: 229, dtype: object
# drug_name          Hypercare
# count                    158
# drug_name_lower    hypercare
# Name: 230, dtype: object
# drug_name          Valium
# count                 157
# drug_name_lower    valium
# Name: 231, dtype: object
# drug_name          Minastrin 24 Fe
# count                          157
# drug_name_lower    minastrin 24 fe
# Name: 232, dtype: object
# drug_name          Norco
# count                156
# drug_name_lower    norco
# Name: 233, dtype: object
# drug_name          Leuprolide
# count                     155
# drug_name_lower    leuprolide
# Name: 234, dtype: object
# drug_name          Valtrex
# count                  155
# drug_name_lower    valtrex
# Name: 235, dtype: object
# drug_name          Cephalexin
# count                     155
# drug_name_lower    cephalexin
# Name: 236, dtype: object
# drug_name          Oxybutynin
# count                     154
# drug_name_lower    oxybutynin
# Name: 237, dtype: object
# drug_name          Drospirenone / ethinyl estradiol / levomefolat...
# count                                                            153
# drug_name_lower    drospirenone / ethinyl estradiol / levomefolat...
# Name: 238, dtype: object
# drug_name          Rizatriptan
# count                      153
# drug_name_lower    rizatriptan
# Name: 239, dtype: object
# drug_name          Depakote
# count                   153
# drug_name_lower    depakote
# Name: 240, dtype: object
# drug_name          Methylprednisolone
# count                             152
# drug_name_lower    methylprednisolone
# Name: 241, dtype: object
# drug_name          Etanercept
# count                     152
# drug_name_lower    etanercept
# Name: 242, dtype: object
# drug_name          Kyleena
# count                  151
# drug_name_lower    kyleena
# Name: 243, dtype: object
# drug_name          Imiquimod
# count                    150
# drug_name_lower    imiquimod
# Name: 244, dtype: object
# drug_name          Drysol
# count                 150
# drug_name_lower    drysol
# Name: 245, dtype: object
# drug_name          Orsythia
# count                   149
# drug_name_lower    orsythia
# Name: 246, dtype: object
# drug_name          Percocet
# count                   148
# drug_name_lower    percocet
# Name: 247, dtype: object
# drug_name          Tizanidine
# count                     147
# drug_name_lower    tizanidine
# Name: 248, dtype: object
# drug_name          MoviPrep
# count                   147
# drug_name_lower    moviprep
# Name: 249, dtype: object
# drug_name          Canagliflozin
# count                        146
# drug_name_lower    canagliflozin
# Name: 250, dtype: object
# drug_name          Ethinyl estradiol / norgestrel
# count                                         146
# drug_name_lower    ethinyl estradiol / norgestrel
# Name: 251, dtype: object
# drug_name          Apremilast
# count                     145
# drug_name_lower    apremilast
# Name: 252, dtype: object
# drug_name          Enbrel
# count                 144
# drug_name_lower    enbrel
# Name: 253, dtype: object
# drug_name          Metoclopramide
# count                         143
# drug_name_lower    metoclopramide
# Name: 254, dtype: object
# drug_name          Invokana
# count                   143
# drug_name_lower    invokana
# Name: 255, dtype: object
# drug_name          Ultram
# count                 142
# drug_name_lower    ultram
# Name: 256, dtype: object
# drug_name          Guaifenesin / pseudoephedrine
# count                                        142
# drug_name_lower    guaifenesin / pseudoephedrine
# Name: 257, dtype: object
# drug_name          Carisoprodol
# count                       141
# drug_name_lower    carisoprodol
# Name: 258, dtype: object
# drug_name          Flagyl
# count                 141
# drug_name_lower    flagyl
# Name: 259, dtype: object
# drug_name          Otezla
# count                 140
# drug_name_lower    otezla
# Name: 260, dtype: object
# drug_name          Amitiza
# count                  140
# drug_name_lower    amitiza
# Name: 261, dtype: object
# drug_name          Neurontin
# count                    140
# drug_name_lower    neurontin
# Name: 262, dtype: object
# drug_name          Lubiprostone
# count                       139
# drug_name_lower    lubiprostone
# Name: 263, dtype: object
# drug_name          Cefdinir
# count                   138
# drug_name_lower    cefdinir
# Name: 264, dtype: object
# drug_name          Ortho Tri-Cyclen
# count                           138
# drug_name_lower    ortho tri-cyclen
# Name: 265, dtype: object
# drug_name          Bydureon
# count                   137
# drug_name_lower    bydureon
# Name: 266, dtype: object
# drug_name          Oxymorphone
# count                      137
# drug_name_lower    oxymorphone
# Name: 267, dtype: object
# drug_name          Bactrim DS
# count                     136
# drug_name_lower    bactrim ds
# Name: 268, dtype: object
# drug_name          Dapsone
# count                  136
# drug_name_lower    dapsone
# Name: 269, dtype: object
# drug_name          Gianvi
# count                 133
# drug_name_lower    gianvi
# Name: 270, dtype: object
# drug_name          Oxcarbazepine
# count                        133
# drug_name_lower    oxcarbazepine
# Name: 271, dtype: object
# drug_name          Ropinirole
# count                     133
# drug_name_lower    ropinirole
# Name: 272, dtype: object
# drug_name          Aczone
# count                 130
# drug_name_lower    aczone
# Name: 273, dtype: object
# drug_name          Tri-Previfem
# count                       130
# drug_name_lower    tri-previfem
# Name: 274, dtype: object
# drug_name          Mononessa
# count                    129
# drug_name_lower    mononessa
# Name: 275, dtype: object
# drug_name          Acetaminophen / butalbital / caffeine
# count                                                129
# drug_name_lower    acetaminophen / butalbital / caffeine
# Name: 276, dtype: object
# drug_name          Promethazine
# count                       129
# drug_name_lower    promethazine
# Name: 277, dtype: object
# drug_name          Methocarbamol
# count                        128
# drug_name_lower    methocarbamol
# Name: 278, dtype: object
# drug_name          Lunesta
# count                  128
# drug_name_lower    lunesta
# Name: 279, dtype: object
# drug_name          Levocetirizine
# count                         127
# drug_name_lower    levocetirizine
# Name: 280, dtype: object
# drug_name          Guanfacine
# count                     127
# drug_name_lower    guanfacine
# Name: 281, dtype: object
# drug_name          Remeron
# count                  127
# drug_name_lower    remeron
# Name: 282, dtype: object
# drug_name          Moxifloxacin
# count                       126
# drug_name_lower    moxifloxacin
# Name: 283, dtype: object
# drug_name          Seroquel XR
# count                      126
# drug_name_lower    seroquel xr
# Name: 284, dtype: object
# drug_name          Dextromethorphan
# count                           122
# drug_name_lower    dextromethorphan
# Name: 285, dtype: object
# drug_name          Zofran
# count                 122
# drug_name_lower    zofran
# Name: 286, dtype: object
# drug_name          Sodium hyaluronate
# count                             122
# drug_name_lower    sodium hyaluronate
# Name: 287, dtype: object
# drug_name          Levora
# count                 122
# drug_name_lower    levora
# Name: 288, dtype: object
# drug_name          Duac
# count               122
# drug_name_lower    duac
# Name: 289, dtype: object
# drug_name          Methotrexate
# count                       121
# drug_name_lower    methotrexate
# Name: 290, dtype: object
# drug_name          Soma
# count               119
# drug_name_lower    soma
# Name: 291, dtype: object
# drug_name          Flexeril
# count                   119
# drug_name_lower    flexeril
# Name: 292, dtype: object
# drug_name          Flomax
# count                 117
# drug_name_lower    flomax
# Name: 293, dtype: object
# drug_name          Diphenhydramine
# count                          117
# drug_name_lower    diphenhydramine
# Name: 294, dtype: object
# drug_name          Toradol
# count                  117
# drug_name_lower    toradol
# Name: 295, dtype: object
# drug_name          Nebivolol
# count                    117
# drug_name_lower    nebivolol
# Name: 296, dtype: object
# drug_name          Keppra
# count                 117
# drug_name_lower    keppra
# Name: 297, dtype: object
# drug_name          Guaifenesin
# count                      117
# drug_name_lower    guaifenesin
# Name: 298, dtype: object
# drug_name          Elavil
# count                 116
# drug_name_lower    elavil
# Name: 299, dtype: object
# drug_name          Risperdal
# count                    116
# drug_name_lower    risperdal
# Name: 300, dtype: object
# drug_name          Fluvoxamine
# count                      116
# drug_name_lower    fluvoxamine
# Name: 301, dtype: object
# drug_name          Amoxicillin
# count                      115
# drug_name_lower    amoxicillin
# Name: 302, dtype: object
# drug_name          Mucinex D
# count                    114
# drug_name_lower    mucinex d
# Name: 303, dtype: object
# drug_name          Atenolol
# count                   114
# drug_name_lower    atenolol
# Name: 304, dtype: object
# drug_name          Hydroxychloroquine
# count                             114
# drug_name_lower    hydroxychloroquine
# Name: 305, dtype: object
# drug_name          Adderall XR
# count                      114
# drug_name_lower    adderall xr
# Name: 306, dtype: object
# drug_name          Imitrex
# count                  114
# drug_name_lower    imitrex
# Name: 307, dtype: object
# drug_name          Polyethylene glycol 3350
# count                                   113
# drug_name_lower    polyethylene glycol 3350
# Name: 308, dtype: object
# drug_name          Viagra
# count                 113
# drug_name_lower    viagra
# Name: 309, dtype: object
# drug_name          Chateal
# count                  113
# drug_name_lower    chateal
# Name: 310, dtype: object
# drug_name          Provigil
# count                   113
# drug_name_lower    provigil
# Name: 311, dtype: object
# drug_name          Xyzal
# count                112
# drug_name_lower    xyzal
# Name: 312, dtype: object
# drug_name          Armour Thyroid
# count                         112
# drug_name_lower    armour thyroid
# Name: 313, dtype: object
# drug_name          Reclipsen
# count                    111
# drug_name_lower    reclipsen
# Name: 314, dtype: object
# drug_name          Voltaren Gel
# count                       111
# drug_name_lower    voltaren gel
# Name: 315, dtype: object
# drug_name          Dicyclomine
# count                      111
# drug_name_lower    dicyclomine
# Name: 316, dtype: object
# drug_name          Fluticasone
# count                      111
# drug_name_lower    fluticasone
# Name: 317, dtype: object
# drug_name          Triamcinolone
# count                        110
# drug_name_lower    triamcinolone
# Name: 318, dtype: object
# drug_name          Meclizine
# count                    110
# drug_name_lower    meclizine
# Name: 319, dtype: object
# drug_name          Vistaril
# count                   110
# drug_name_lower    vistaril
# Name: 320, dtype: object
# drug_name          Acamprosate
# count                      109
# drug_name_lower    acamprosate
# Name: 321, dtype: object
# drug_name          Celecoxib
# count                    109
# drug_name_lower    celecoxib
# Name: 322, dtype: object
# drug_name          Alesse
# count                 109
# drug_name_lower    alesse
# Name: 323, dtype: object
# drug_name          Dexlansoprazole
# count                          109
# drug_name_lower    dexlansoprazole
# Name: 324, dtype: object
# drug_name          Infliximab
# count                     109
# drug_name_lower    infliximab
# Name: 325, dtype: object
# drug_name          Cetirizine
# count                     108
# drug_name_lower    cetirizine
# Name: 326, dtype: object
# drug_name          Butrans
# count                  107
# drug_name_lower    butrans
# Name: 327, dtype: object
# drug_name          Generess Fe
# count                      106
# drug_name_lower    generess fe
# Name: 328, dtype: object
# drug_name          Paliperidone
# count                       104
# drug_name_lower    paliperidone
# Name: 329, dtype: object
# drug_name          Remicade
# count                   104
# drug_name_lower    remicade
# Name: 330, dtype: object
# drug_name          Acetaminophen / codeine
# count                                  103
# drug_name_lower    acetaminophen / codeine
# Name: 331, dtype: object
# drug_name          Melatonin
# count                    103
# drug_name_lower    melatonin
# Name: 332, dtype: object
# drug_name          Indomethacin
# count                       103
# drug_name_lower    indomethacin
# Name: 333, dtype: object
# drug_name          Bystolic
# count                   103
# drug_name_lower    bystolic
# Name: 334, dtype: object
# drug_name          Avelox
# count                 102
# drug_name_lower    avelox
# Name: 335, dtype: object
# drug_name          Movantik
# count                   102
# drug_name_lower    movantik
# Name: 336, dtype: object
# drug_name          Dexmethylphenidate
# count                             101
# drug_name_lower    dexmethylphenidate
# Name: 337, dtype: object
# drug_name          Levomilnacipran
# count                          101
# drug_name_lower    levomilnacipran
# Name: 338, dtype: object
#                               drug_name  count           CID
# 0                        Levonorgestrel   3657  CID100002909
# 10   Ethinyl estradiol / levonorgestrel   1888  CID100002909
# 19                          Venlafaxine   1016  CID100002909
# 39                             Contrave    920  CID100002909
# 44                         Depo-Provera    882  CID100002909
# ..                                  ...    ...           ...
# 427                        Paliperidone    104  CID100071360
# 428                        Paliperidone    104  CID100115237
# 430             Acetaminophen / codeine    103  CID100002828
# 431                           Melatonin    103  CID100000896
# 432                        Indomethacin    103  CID100003715
#
# [441 rows x 3 columns]
