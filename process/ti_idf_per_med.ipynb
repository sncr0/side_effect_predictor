# %%
import pandas as pd
import csv
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
dataset_path = "/home/samuel/NYU/BDS/project/review_dataset/"

def read_tsv_file(file_path):
    try:
        data = []
        with open(file_path, 'r', newline='', encoding='utf-8') as file:
            # Using the CSV reader with the tab delimiter
            reader = csv.reader(file, delimiter='\t')

            # Reading headers
            headers = next(reader)
            print("Headers:", headers)

            # Reading data rows
            for row in reader:
                data.append(row)

        # Create a Pandas DataFrame using the headers and data
        df = pd.DataFrame(data, columns=headers)
        return df

    except FileNotFoundError:
        print(f"Error: File not found at '{file_path}'")
    except Exception as e:
        print(f"An error occurred: {e}")
file_path = dataset_path + 'drugsComTrain_raw.tsv'
dataset = read_tsv_file(file_path)
# Out:
# Headers: ['', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount']

# %%
def process_dataset_df(dataset):
    processed_reviews = []

    for index, row in dataset.iterrows():
        if index % 50000 == 0:
            print(index)
        # Assuming the review text is in a column named 'review'
        review_text = row['review']

        # HTML decoding
        text_html = BeautifulSoup(review_text, 'html.parser').get_text()

        # Tokenization and removal of stop words
        stop_words = set(stopwords.words('english'))
        words = [word.lower() for word in text_html.split() if word.lower() not in stop_words]

        # Stemming
        stemmer = PorterStemmer()
        stemmed_words = [stemmer.stem(word) for word in words]

        # Join the processed words back into a single string
        processed_text = ' '.join(stemmed_words)

        processed_reviews.append(processed_text)

    # Add a new column 'processed_review' to the DataFrame
    dataset['processed_review'] = processed_reviews

    return dataset
processed_dataset = process_dataset_df(dataset)
# Out:
# 0
# /tmp/ipykernel_323456/4166812629.py:11: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_html = BeautifulSoup(review_text, 'html.parser').get_text()
# 50000
# 100000
# 150000

# %%
drug_names = processed_dataset['drugName'].value_counts()

# Create an empty DataFrame to store TF-IDF results for each drug name
tfidf_results = pd.DataFrame()
tfidf_results_dict = {}

# Initialize the TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=100)

# Iterate over each unique drug name and compute TF-IDF separately
for drug_name in drug_names.iloc[0:10].index:
    # Filter the dataset for the current drug name
    drug_dataset = processed_dataset[processed_dataset['drugName'] == drug_name]
    
    # Compute TF-IDF for the 'processed_review' column of the filtered dataset
    tfidf_matrix = vectorizer.fit_transform(drug_dataset['processed_review'])
    
    # Convert TF-IDF matrix to DataFrame and add drug name as a column
    tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
    tfidf_df['drugName'] = drug_name
    
    # Append TF-IDF results for the current drug name to the overall results DataFrame
    tfidf_results_dict[drug_name] = tfidf_df
# Print the TF-IDF results
print("TF-IDF Results:")
print(tfidf_results_dict)
# Out:
# TF-IDF Results:
# {'Levonorgestrel':             10       ago    almost      also  back       bad     birth  \
# 0     0.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.000000
# 1     0.000000  0.181273  0.410771  0.000000   0.0  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.000000
# 3     0.279302  0.000000  0.284351  0.000000   0.0  0.000000  0.229721
# 4     0.213656  0.191981  0.000000  0.395117   0.0  0.171630  0.000000
# ...        ...       ...       ...       ...   ...       ...       ...
# 3652  0.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.273556
# 3653  0.000000  0.000000  0.000000  0.199731   0.0  0.000000  0.000000
# 3654  0.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.000000
# 3655  0.164207  0.147549  0.000000  0.303671   0.0  0.000000  0.135057
# 3656  0.174998  0.000000  0.178161  0.000000   0.0  0.140576  0.000000
#
#          bleed  boyfriend     came  ...       use      want      week  \
# 0     0.000000        0.0  0.00000  ...  0.000000  0.000000  0.206600
# 1     0.000000        0.0  0.00000  ...  0.000000  0.194217  0.000000
# 2     0.000000        0.0  0.00000  ...  0.000000  0.000000  0.000000
# 3     0.000000        0.0  0.00000  ...  0.000000  0.268888  0.000000
# 4     0.000000        0.0  0.00000  ...  0.000000  0.000000  0.135828
# ...        ...        ...      ...  ...       ...       ...       ...
# 3652  0.000000        0.0  0.00000  ...  0.000000  0.000000  0.000000
# 3653  0.000000        0.0  0.21068  ...  0.000000  0.000000  0.137322
# 3654  0.000000        0.0  0.00000  ...  0.000000  0.204766  0.000000
# 3655  0.136245        0.0  0.00000  ...  0.150337  0.000000  0.000000
# 3656  0.000000        0.0  0.00000  ...  0.160216  0.168473  0.111252
#
#         weight      went      work  worri     would      year        drugName
# 0     0.000000  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 1     0.000000  0.000000  0.000000    0.0  0.161105  0.471408  Levonorgestrel
# 2     0.000000  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 3     0.267086  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 4     0.000000  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# ...        ...       ...       ...    ...       ...       ...             ...
# 3652  0.318051  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 3653  0.000000  0.000000  0.337452    0.0  0.000000  0.000000  Levonorgestrel
# 3654  0.000000  0.367012  0.000000    0.0  0.000000  0.165671  Levonorgestrel
# 3655  0.157025  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 3656  0.000000  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
#
# [3657 rows x 101 columns], 'Etonogestrel':           2015  acn  ago       all    almost      also  alway       arm  \
# 0     0.000000  0.0  0.0  0.000000  0.000000  0.214157    0.0  0.000000
# 1     0.000000  0.0  0.0  0.000000  0.000000  0.000000    0.0  0.000000
# 2     0.000000  0.0  0.0  0.000000  0.000000  0.000000    0.0  0.000000
# 3     0.000000  0.0  0.0  0.206206  0.000000  0.000000    0.0  0.000000
# 4     0.000000  0.0  0.0  0.000000  0.000000  0.149189    0.0  0.000000
# ...        ...  ...  ...       ...       ...       ...    ...       ...
# 3331  0.000000  0.0  0.0  0.000000  0.000000  0.188909    0.0  0.000000
# 3332  0.000000  0.0  0.0  0.000000  0.000000  0.000000    0.0  0.000000
# 3333  0.397804  0.0  0.0  0.000000  0.000000  0.000000    0.0  0.181755
# 3334  0.000000  0.0  0.0  0.000000  0.176567  0.000000    0.0  0.000000
# 3335  0.000000  0.0  0.0  0.000000  0.000000  0.216050    0.0  0.000000
#
#           back       bad  ...      week    weight  well      went  work  \
# 0     0.000000  0.000000  ...  0.000000  0.000000   0.0  0.000000   0.0
# 1     0.000000  0.000000  ...  0.243253  0.000000   0.0  0.000000   0.0
# 2     0.000000  0.000000  ...  0.234337  0.220729   0.0  0.000000   0.0
# 3     0.000000  0.000000  ...  0.509866  0.120065   0.0  0.199282   0.0
# 4     0.000000  0.000000  ...  0.000000  0.106830   0.0  0.177314   0.0
# ...        ...       ...  ...       ...       ...   ...       ...   ...
# 3331  0.000000  0.000000  ...  0.000000  0.270544   0.0  0.000000   0.0
# 3332  0.000000  0.238094  ...  0.000000  0.000000   0.0  0.000000   0.0
# 3333  0.000000  0.000000  ...  0.000000  0.000000   0.0  0.000000   0.0
# 3334  0.000000  0.000000  ...  0.120285  0.113301   0.0  0.000000   0.0
# 3335  0.225008  0.000000  ...  0.000000  0.000000   0.0  0.000000   0.0
#
#          worri     would      year  years      drugName
# 0     0.266057  0.000000  0.000000    0.0  Etonogestrel
# 1     0.000000  0.000000  0.000000    0.0  Etonogestrel
# 2     0.000000  0.000000  0.000000    0.0  Etonogestrel
# 3     0.000000  0.000000  0.000000    0.0  Etonogestrel
# 4     0.000000  0.000000  0.216636    0.0  Etonogestrel
# ...        ...       ...       ...    ...           ...
# 3331  0.000000  0.000000  0.274313    0.0  Etonogestrel
# 3332  0.000000  0.000000  0.000000    0.0  Etonogestrel
# 3333  0.000000  0.000000  0.119644    0.0  Etonogestrel
# 3334  0.196571  0.000000  0.000000    0.0  Etonogestrel
# 3335  0.000000  0.375897  0.000000    0.0  Etonogestrel
#
# [3336 rows x 101 columns], 'Ethinyl estradiol / norethindrone':            acn  acne    almost      also     alway      back       bad  \
# 0     0.000000   0.0  0.000000  0.000000  0.000000  0.157392  0.294799
# 1     0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.000000   0.0  0.175861  0.000000  0.000000  0.000000  0.151172
# 3     0.000000   0.0  0.000000  0.167309  0.000000  0.000000  0.000000
# 4     0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# ...        ...   ...       ...       ...       ...       ...       ...
# 2845  0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2846  0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2847  0.294023   0.0  0.000000  0.000000  0.187813  0.158830  0.000000
# 2848  0.154046   0.0  0.000000  0.000000  0.000000  0.166430  0.000000
# 2849  0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             bc     birth     bleed  ...       use  want      week    weight  \
# 0     0.000000  0.000000  0.000000  ...  0.153130   0.0  0.249580  0.000000
# 1     0.000000  0.000000  0.000000  ...  0.000000   0.0  0.000000  0.221360
# 2     0.192382  0.000000  0.000000  ...  0.000000   0.0  0.000000  0.000000
# 3     0.000000  0.128648  0.000000  ...  0.000000   0.0  0.000000  0.137728
# 4     0.000000  0.000000  0.000000  ...  0.161267   0.0  0.000000  0.000000
# ...        ...       ...       ...  ...       ...   ...       ...       ...
# 2845  0.000000  0.000000  0.000000  ...  0.000000   0.0  0.000000  0.339779
# 2846  0.574504  0.000000  0.162990  ...  0.000000   0.0  0.127398  0.000000
# 2847  0.000000  0.107811  0.000000  ...  0.000000   0.0  0.000000  0.000000
# 2848  0.198352  0.000000  0.000000  ...  0.000000   0.0  0.000000  0.000000
# 2849  0.000000  0.119316  0.178304  ...  0.000000   0.0  0.000000  0.127737
#
#           well      went  work     would      year  \
# 0     0.549866  0.000000   0.0  0.000000  0.126452
# 1     0.000000  0.000000   0.0  0.000000  0.000000
# 2     0.000000  0.000000   0.0  0.000000  0.000000
# 3     0.000000  0.000000   0.0  0.000000  0.456811
# 4     0.000000  0.354347   0.0  0.146416  0.000000
# ...        ...       ...   ...       ...       ...
# 2845  0.000000  0.000000   0.0  0.413016  0.000000
# 2846  0.000000  0.000000   0.0  0.000000  0.129095
# 2847  0.000000  0.000000   0.0  0.140299  0.127607
# 2848  0.000000  0.177895   0.0  0.147012  0.000000
# 2849  0.000000  0.000000   0.0  0.000000  0.000000
#
#                                drugName
# 0     Ethinyl estradiol / norethindrone
# 1     Ethinyl estradiol / norethindrone
# 2     Ethinyl estradiol / norethindrone
# 3     Ethinyl estradiol / norethindrone
# 4     Ethinyl estradiol / norethindrone
# ...                                 ...
# 2845  Ethinyl estradiol / norethindrone
# 2846  Ethinyl estradiol / norethindrone
# 2847  Ethinyl estradiol / norethindrone
# 2848  Ethinyl estradiol / norethindrone
# 2849  Ethinyl estradiol / norethindrone
#
# [2850 rows x 101 columns], 'Nexplanon':           2015       acn       ago  all  almost  also     alway      arm  \
# 0     0.000000  0.136437  0.145431  0.0     0.0   0.0  0.000000  0.00000
# 1     0.000000  0.000000  0.000000  0.0     0.0   0.0  0.000000  0.00000
# 2     0.000000  0.374938  0.000000  0.0     0.0   0.0  0.199559  0.00000
# 3     0.000000  0.103444  0.000000  0.0     0.0   0.0  0.000000  0.10032
# 4     0.000000  0.000000  0.000000  0.0     0.0   0.0  0.000000  0.00000
# ...        ...       ...       ...  ...     ...   ...       ...      ...
# 2151  0.000000  0.000000  0.236154  0.0     0.0   0.0  0.000000  0.00000
# 2152  0.000000  0.000000  0.000000  0.0     0.0   0.0  0.000000  0.00000
# 2153  0.143223  0.000000  0.000000  0.0     0.0   0.0  0.000000  0.00000
# 2154  0.000000  0.000000  0.000000  0.0     0.0   0.0  0.305366  0.00000
# 2155  0.000000  0.000000  0.000000  0.0     0.0   0.0  0.000000  0.00000
#
#           back       bad  ...      want      week    weight      well  \
# 0     0.123358  0.000000  ...  0.130042  0.088782  0.000000  0.000000
# 1     0.000000  0.000000  ...  0.000000  0.189512  0.377143  0.000000
# 2     0.000000  0.503156  ...  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.092546  ...  0.000000  0.471192  0.000000  0.000000
# 4     0.000000  0.000000  ...  0.000000  0.145266  0.000000  0.000000
# ...        ...       ...  ...       ...       ...       ...       ...
# 2151  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2152  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2153  0.000000  0.000000  ...  0.000000  0.188568  0.000000  0.161829
# 2154  0.000000  0.000000  ...  0.136710  0.000000  0.092872  0.000000
# 2155  0.000000  0.000000  ...  0.000000  0.115536  0.114963  0.000000
#
#          went      work  worst     would      year   drugName
# 0     0.00000  0.000000    0.0  0.000000  0.000000  Nexplanon
# 1     0.00000  0.000000    0.0  0.000000  0.191179  Nexplanon
# 2     0.00000  0.000000    0.0  0.000000  0.000000  Nexplanon
# 3     0.00000  0.100100    0.0  0.000000  0.339527  Nexplanon
# 4     0.00000  0.000000    0.0  0.000000  0.293087  Nexplanon
# ...       ...       ...    ...       ...       ...        ...
# 2151  0.00000  0.000000    0.0  0.169082  0.145435  Nexplanon
# 2152  0.00000  0.372247    0.0  0.000000  0.000000  Nexplanon
# 2153  0.15182  0.000000    0.0  0.221156  0.095113  Nexplanon
# 2154  0.00000  0.000000    0.0  0.000000  0.094156  Nexplanon
# 2155  0.00000  0.000000    0.0  0.000000  0.000000  Nexplanon
#
# [2156 rows x 101 columns], 'Ethinyl estradiol / norgestimate':            acn  acne    almost      also     alway      back       bad  \
# 0     0.352951   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.229612   0.0  0.000000  0.000000  0.000000  0.285608  0.000000
# 2     0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.000000   0.0  0.000000  0.125371  0.000000  0.000000  0.131843
# 4     0.000000   0.0  0.000000  0.176616  0.000000  0.000000  0.000000
# ...        ...   ...       ...       ...       ...       ...       ...
# 2112  0.000000   0.0  0.161134  0.000000  0.000000  0.310577  0.137906
# 2113  0.159178   0.0  0.000000  0.000000  0.000000  0.197997  0.000000
# 2114  0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2115  0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2116  0.000000   0.0  0.000000  0.000000  0.236507  0.000000  0.186419
#
#             bc    better     birth  ...  two       use      week    weight  \
# 0     0.000000  0.000000  0.290471  ...  0.0  0.000000  0.000000  0.000000
# 1     0.000000  0.330969  0.000000  ...  0.0  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.000000
# 3     0.356394  0.000000  0.000000  ...  0.0  0.000000  0.113313  0.000000
# 4     0.000000  0.000000  0.138376  ...  0.0  0.185232  0.000000  0.000000
# ...        ...       ...       ...  ...  ...       ...       ...       ...
# 2112  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.235846
# 2113  0.000000  0.000000  0.000000  ...  0.0  0.175359  0.151121  0.150355
# 2114  0.344376  0.332478  0.000000  ...  0.0  0.000000  0.000000  0.000000
# 2115  0.403870  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.000000
# 2116  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.160219  0.318814
#
#           well      went      work     would      year  \
# 0     0.000000  0.000000  0.605262  0.000000  0.000000
# 1     0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  0.226827  0.000000
# 3     0.000000  0.148960  0.000000  0.000000  0.000000
# 4     0.225868  0.209847  0.000000  0.000000  0.162235
# ...        ...       ...       ...       ...       ...
# 2112  0.000000  0.311620  0.000000  0.000000  0.240916
# 2113  0.000000  0.000000  0.181979  0.172883  0.153587
# 2114  0.000000  0.000000  0.000000  0.000000  0.000000
# 2115  0.000000  0.000000  0.000000  0.000000  0.391509
# 2116  0.000000  0.210622  0.000000  0.000000  0.000000
#
#                               drugName
# 0     Ethinyl estradiol / norgestimate
# 1     Ethinyl estradiol / norgestimate
# 2     Ethinyl estradiol / norgestimate
# 3     Ethinyl estradiol / norgestimate
# 4     Ethinyl estradiol / norgestimate
# ...                                ...
# 2112  Ethinyl estradiol / norgestimate
# 2113  Ethinyl estradiol / norgestimate
# 2114  Ethinyl estradiol / norgestimate
# 2115  Ethinyl estradiol / norgestimate
# 2116  Ethinyl estradiol / norgestimate
#
# [2117 rows x 101 columns], 'Ethinyl estradiol / levonorgestrel':            acn      acne  almost      also     alway  avian      back  \
# 0     0.165605  0.198199     0.0  0.310533  0.000000    0.0  0.175708
# 1     0.000000  0.000000     0.0  0.174028  0.232979    0.0  0.000000
# 2     0.000000  0.000000     0.0  0.000000  0.000000    0.0  0.000000
# 3     0.236585  0.000000     0.0  0.000000  0.000000    0.0  0.000000
# 4     0.000000  0.000000     0.0  0.000000  0.000000    0.0  0.000000
# ...        ...       ...     ...       ...       ...    ...       ...
# 1883  0.162400  0.000000     0.0  0.000000  0.000000    0.0  0.000000
# 1884  0.000000  0.000000     0.0  0.000000  0.000000    0.0  0.000000
# 1885  0.000000  0.000000     0.0  0.000000  0.000000    0.0  0.000000
# 1886  0.167798  0.000000     0.0  0.157323  0.000000    0.0  0.000000
# 1887  0.000000  0.000000     0.0  0.000000  0.000000    0.0  0.000000
#
#            bad    better     birth  ...       two       use     want  \
# 0     0.000000  0.000000  0.115924  ...  0.000000  0.163871  0.00000
# 1     0.000000  0.000000  0.129931  ...  0.000000  0.000000  0.00000
# 2     0.145892  0.000000  0.197890  ...  0.155958  0.000000  0.17595
# 3     0.000000  0.000000  0.165610  ...  0.000000  0.000000  0.00000
# 4     0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.00000
# ...        ...       ...       ...  ...       ...       ...      ...
# 1883  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.00000
# 1884  0.000000  0.166893  0.000000  ...  0.000000  0.000000  0.00000
# 1885  0.129415  0.000000  0.000000  ...  0.000000  0.000000  0.00000
# 1886  0.173191  0.000000  0.000000  ...  0.000000  0.000000  0.00000
# 1887  0.000000  0.000000  0.233513  ...  0.000000  0.000000  0.00000
#
#           week    weight      went      work     would      year  \
# 0     0.000000  0.271356  0.000000  0.000000  0.000000  0.000000
# 1     0.000000  0.152072  0.000000  0.000000  0.000000  0.155557
# 2     0.000000  0.000000  0.000000  0.149271  0.000000  0.000000
# 3     0.556282  0.000000  0.000000  0.000000  0.000000  0.198273
# 4     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...        ...       ...       ...       ...       ...       ...
# 1883  0.000000  0.133053  0.000000  0.000000  0.000000  0.272203
# 1884  0.000000  0.000000  0.000000  0.000000  0.369752  0.000000
# 1885  0.393089  0.000000  0.000000  0.000000  0.000000  0.000000
# 1886  0.131514  0.000000  0.381077  0.000000  0.000000  0.000000
# 1887  0.000000  0.000000  0.378799  0.000000  0.000000  0.000000
#
#                                 drugName
# 0     Ethinyl estradiol / levonorgestrel
# 1     Ethinyl estradiol / levonorgestrel
# 2     Ethinyl estradiol / levonorgestrel
# 3     Ethinyl estradiol / levonorgestrel
# 4     Ethinyl estradiol / levonorgestrel
# ...                                  ...
# 1883  Ethinyl estradiol / levonorgestrel
# 1884  Ethinyl estradiol / levonorgestrel
# 1885  Ethinyl estradiol / levonorgestrel
# 1886  Ethinyl estradiol / levonorgestrel
# 1887  Ethinyl estradiol / levonorgestrel
#
# [1888 rows x 101 columns], 'Phentermine':            10        15   16        20   30        37    adipex       ago  \
# 0     0.00000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.000000
# 1     0.00000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.000000
# 2     0.00000  0.348358  0.0  0.000000  0.0  0.000000  0.000000  0.000000
# 3     0.00000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.000000
# 4     0.00000  0.000000  0.0  0.000000  0.0  0.000000  0.141106  0.000000
# ...       ...       ...  ...       ...  ...       ...       ...       ...
# 1538  0.00000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.000000
# 1539  0.00000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.000000
# 1540  0.00000  0.000000  0.0  0.000000  0.0  0.352364  0.000000  0.000000
# 1541  0.15267  0.000000  0.0  0.000000  0.0  0.000000  0.294741  0.000000
# 1542  0.00000  0.000000  0.0  0.342251  0.0  0.000000  0.270043  0.292383
#
#           also  appetit  ...  water      week     weigh    weight      well  \
# 0     0.000000      0.0  ...    0.0  0.000000  0.000000  0.130443  0.000000
# 1     0.000000      0.0  ...    0.0  0.241703  0.136874  0.101286  0.215904
# 2     0.000000      0.0  ...    0.0  0.107336  0.121567  0.089958  0.000000
# 3     0.000000      0.0  ...    0.0  0.000000  0.252762  0.187042  0.000000
# 4     0.000000      0.0  ...    0.0  0.000000  0.000000  0.246736  0.000000
# ...        ...      ...  ...    ...       ...       ...       ...       ...
# 1538  0.000000      0.0  ...    0.0  0.000000  0.000000  0.000000  0.000000
# 1539  0.000000      0.0  ...    0.0  0.165088  0.000000  0.138360  0.000000
# 1540  0.000000      0.0  ...    0.0  0.000000  0.000000  0.203121  0.432980
# 1541  0.441507      0.0  ...    0.0  0.102490  0.000000  0.085897  0.000000
# 1542  0.000000      0.0  ...    0.0  0.375607  0.000000  0.000000  0.000000
#
#           went      work     would  year     drugName
# 0     0.000000  0.000000  0.471316   0.0  Phentermine
# 1     0.000000  0.000000  0.000000   0.0  Phentermine
# 2     0.000000  0.119946  0.325037   0.0  Phentermine
# 3     0.000000  0.000000  0.000000   0.0  Phentermine
# 4     0.000000  0.000000  0.148584   0.0  Phentermine
# ...        ...       ...       ...   ...          ...
# 1538  0.000000  0.000000  0.000000   0.0  Phentermine
# 1539  0.000000  0.000000  0.000000   0.0  Phentermine
# 1540  0.367511  0.000000  0.000000   0.0  Phentermine
# 1541  0.000000  0.000000  0.000000   0.0  Phentermine
# 1542  0.000000  0.000000  0.000000   0.0  Phentermine
#
# [1543 rows x 101 columns], 'Sertraline':          100mg      25mg        50      50mg  again       ago  almost  \
# 0     0.000000  0.000000  0.000000  0.240109    0.0  0.000000     0.0
# 1     0.000000  0.000000  0.167382  0.000000    0.0  0.285212     0.0
# 2     0.320915  0.000000  0.000000  0.252720    0.0  0.000000     0.0
# 3     0.000000  0.000000  0.000000  0.000000    0.0  0.261105     0.0
# 4     0.000000  0.000000  0.000000  0.000000    0.0  0.000000     0.0
# ...        ...       ...       ...       ...    ...       ...     ...
# 1355  0.000000  0.000000  0.249893  0.000000    0.0  0.000000     0.0
# 1356  0.000000  0.000000  0.000000  0.000000    0.0  0.283549     0.0
# 1357  0.000000  0.000000  0.000000  0.000000    0.0  0.000000     0.0
# 1358  0.164726  0.165375  0.177416  0.259442    0.0  0.000000     0.0
# 1359  0.000000  0.000000  0.000000  0.000000    0.0  0.000000     0.0
#
#           also   anxieti   anxiety  ...     weeks    weight      well  \
# 0     0.000000  0.189025  0.000000  ...  0.000000  0.000000  0.000000
# 1     0.135595  0.192693  0.000000  ...  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 3     0.000000  0.176406  0.000000  ...  0.000000  0.000000  0.000000
# 4     0.000000  0.132996  0.176723  ...  0.000000  0.000000  0.000000
# ...        ...       ...       ...  ...       ...       ...       ...
# 1355  0.202437  0.143841  0.000000  ...  0.000000  0.000000  0.000000
# 1356  0.269608  0.000000  0.000000  ...  0.336731  0.335144  0.000000
# 1357  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1358  0.287447  0.204245  0.000000  ...  0.000000  0.000000  0.000000
# 1359  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.371737
#
#           went      work     would      year     years    zoloft    drugName
# 0     0.284027  0.000000  0.000000  0.000000  0.000000  0.162348  Sertraline
# 1     0.000000  0.325885  0.133201  0.107919  0.000000  0.165498  Sertraline
# 2     0.298944  0.224314  0.000000  0.222850  0.000000  0.000000  Sertraline
# 3     0.265066  0.198893  0.000000  0.197595  0.000000  0.000000  Sertraline
# 4     0.000000  0.000000  0.000000  0.000000  0.442259  0.000000  Sertraline
# ...        ...       ...       ...       ...       ...       ...         ...
# 1355  0.000000  0.000000  0.000000  0.000000  0.000000  0.123541  Sertraline
# 1356  0.000000  0.000000  0.000000  0.000000  0.000000  0.164533  Sertraline
# 1357  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  Sertraline
# 1358  0.153448  0.115140  0.000000  0.000000  0.000000  0.175419  Sertraline
# 1359  0.000000  0.262366  0.000000  0.000000  0.000000  0.199860  Sertraline
#
# [1360 rows x 101 columns], 'Escitalopram':             10      10mg   20  20mg  5mg     again  ago  almost      also  \
# 0     0.000000  0.000000  0.0   0.0  0.0  0.318698  0.0     0.0  0.000000
# 1     0.000000  0.000000  0.0   0.0  0.0  0.000000  0.0     0.0  0.284764
# 2     0.000000  0.286271  0.0   0.0  0.0  0.000000  0.0     0.0  0.000000
# 3     0.000000  0.000000  0.0   0.0  0.0  0.000000  0.0     0.0  0.198089
# 4     0.163217  0.000000  0.0   0.0  0.0  0.193808  0.0     0.0  0.344798
# ...        ...       ...  ...   ...  ...       ...  ...     ...       ...
# 1287  0.000000  0.000000  0.0   0.0  0.0  0.000000  0.0     0.0  0.228223
# 1288  0.140564  0.000000  0.0   0.0  0.0  0.000000  0.0     0.0  0.000000
# 1289  0.172701  0.000000  0.0   0.0  0.0  0.000000  0.0     0.0  0.000000
# 1290  0.000000  0.000000  0.0   0.0  0.0  0.000000  0.0     0.0  0.000000
# 1291  0.000000  0.000000  0.0   0.0  0.0  0.000000  0.0     0.0  0.359398
#
#        anxieti  ...  want      week    weight      well      went      work  \
# 0     0.000000  ...   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.175186  ...   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.189430  ...   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  ...   0.0  0.138378  0.224128  0.226095  0.000000  0.000000
# 4     0.106060  ...   0.0  0.120431  0.000000  0.000000  0.000000  0.000000
# ...        ...  ...   ...       ...       ...       ...       ...       ...
# 1287  0.140402  ...   0.0  0.000000  0.000000  0.000000  0.000000  0.179337
# 1288  0.091339  ...   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1289  0.224445  ...   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1290  0.000000  ...   0.0  0.000000  0.000000  0.000000  0.000000  0.591931
# 1291  0.000000  ...   0.0  0.125531  0.000000  0.000000  0.364352  0.000000
#
#          would      year     years      drugName
# 0     0.000000  0.000000  0.000000  Escitalopram
# 1     0.000000  0.000000  0.000000  Escitalopram
# 2     0.000000  0.240547  0.000000  Escitalopram
# 3     0.000000  0.000000  0.230201  Escitalopram
# 4     0.334735  0.134680  0.000000  Escitalopram
# ...        ...       ...       ...           ...
# 1287  0.000000  0.000000  0.000000  Escitalopram
# 1288  0.000000  0.000000  0.172539  Escitalopram
# 1289  0.177092  0.142505  0.211988  Escitalopram
# 1290  0.000000  0.000000  0.000000  Escitalopram
# 1291  0.000000  0.000000  0.000000  Escitalopram
#
# [1292 rows x 101 columns], 'Mirena':             10       acn       ago  all  almost      also      back       bad  \
# 0     0.000000  0.237791  0.182885  0.0     0.0  0.000000  0.000000  0.000000
# 1     0.000000  0.000000  0.000000  0.0     0.0  0.000000  0.000000  0.000000
# 2     0.518636  0.000000  0.000000  0.0     0.0  0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.000000  0.0     0.0  0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.000000  0.0     0.0  0.000000  0.000000  0.235642
# ...        ...       ...       ...  ...     ...       ...       ...       ...
# 1237  0.000000  0.000000  0.000000  0.0     0.0  0.252429  0.000000  0.000000
# 1238  0.000000  0.000000  0.000000  0.0     0.0  0.000000  0.185972  0.000000
# 1239  0.000000  0.000000  0.000000  0.0     0.0  0.000000  0.170557  0.000000
# 1240  0.000000  0.000000  0.000000  0.0     0.0  0.000000  0.000000  0.000000
# 1241  0.000000  0.000000  0.000000  0.0     0.0  0.000000  0.000000  0.000000
#
#          birth     bleed  ...       use      want      week    weight  \
# 0     0.171285  0.000000  ...  0.200644  0.000000  0.000000  0.000000
# 1     0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  ...  0.000000  0.238848  0.000000  0.000000
# 3     0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# ...        ...       ...  ...       ...       ...       ...       ...
# 1237  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.220412
# 1238  0.000000  0.000000  ...  0.000000  0.000000  0.138814  0.000000
# 1239  0.000000  0.000000  ...  0.342338  0.000000  0.000000  0.589407
# 1240  0.136719  0.248684  ...  0.000000  0.493945  0.000000  0.000000
# 1241  0.000000  0.000000  ...  0.239037  0.000000  0.177785  0.000000
#
#           went      work    would      year     years  drugName
# 0     0.000000  0.000000  0.00000  0.000000  0.443944    Mirena
# 1     0.000000  0.000000  0.00000  0.119592  0.196471    Mirena
# 2     0.000000  0.000000  0.00000  0.000000  0.000000    Mirena
# 3     0.000000  0.000000  0.00000  0.255970  0.000000    Mirena
# 4     0.000000  0.288201  0.00000  0.000000  0.000000    Mirena
# ...        ...       ...      ...       ...       ...       ...
# 1237  0.000000  0.000000  0.00000  0.172416  0.000000    Mirena
# 1238  0.194096  0.196783  0.00000  0.000000  0.206479    Mirena
# 1239  0.000000  0.000000  0.00000  0.115265  0.000000    Mirena
# 1240  0.000000  0.000000  0.13653  0.215695  0.000000    Mirena
# 1241  0.000000  0.000000  0.00000  0.160968  0.000000    Mirena
#
# [1242 rows x 101 columns]}

# %%
tfidf_results_dict["Levonorgestrel"]
# Out:
#             10       ago    almost      also  back       bad     birth  \
# 0     0.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.000000
# 1     0.000000  0.181273  0.410771  0.000000   0.0  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.000000
# 3     0.279302  0.000000  0.284351  0.000000   0.0  0.000000  0.229721
# 4     0.213656  0.191981  0.000000  0.395117   0.0  0.171630  0.000000
# ...        ...       ...       ...       ...   ...       ...       ...
# 3652  0.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.273556
# 3653  0.000000  0.000000  0.000000  0.199731   0.0  0.000000  0.000000
# 3654  0.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.000000
# 3655  0.164207  0.147549  0.000000  0.303671   0.0  0.000000  0.135057
# 3656  0.174998  0.000000  0.178161  0.000000   0.0  0.140576  0.000000
#
#          bleed  boyfriend     came  ...       use      want      week  \
# 0     0.000000        0.0  0.00000  ...  0.000000  0.000000  0.206600
# 1     0.000000        0.0  0.00000  ...  0.000000  0.194217  0.000000
# 2     0.000000        0.0  0.00000  ...  0.000000  0.000000  0.000000
# 3     0.000000        0.0  0.00000  ...  0.000000  0.268888  0.000000
# 4     0.000000        0.0  0.00000  ...  0.000000  0.000000  0.135828
# ...        ...        ...      ...  ...       ...       ...       ...
# 3652  0.000000        0.0  0.00000  ...  0.000000  0.000000  0.000000
# 3653  0.000000        0.0  0.21068  ...  0.000000  0.000000  0.137322
# 3654  0.000000        0.0  0.00000  ...  0.000000  0.204766  0.000000
# 3655  0.136245        0.0  0.00000  ...  0.150337  0.000000  0.000000
# 3656  0.000000        0.0  0.00000  ...  0.160216  0.168473  0.111252
#
#         weight      went      work  worri     would      year        drugName
# 0     0.000000  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 1     0.000000  0.000000  0.000000    0.0  0.161105  0.471408  Levonorgestrel
# 2     0.000000  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 3     0.267086  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 4     0.000000  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# ...        ...       ...       ...    ...       ...       ...             ...
# 3652  0.318051  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 3653  0.000000  0.000000  0.337452    0.0  0.000000  0.000000  Levonorgestrel
# 3654  0.000000  0.367012  0.000000    0.0  0.000000  0.165671  Levonorgestrel
# 3655  0.157025  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
# 3656  0.000000  0.000000  0.000000    0.0  0.000000  0.000000  Levonorgestrel
#
# [3657 rows x 101 columns]
